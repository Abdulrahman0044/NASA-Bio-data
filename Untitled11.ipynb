# %%
import requests

api_url = "https://genelab-data.ndc.nasa.gov/genelab/data/glds/files/137,86-87"

headers = {
    'Accept': 'application/json',
    'content-type': 'application/json',
}

response = requests.get(api_url, headers=headers)
myjson = response.json()
print(myjson)
# Out:
# {'hits': 3, 'input': '137,86-87', 'page_number': 1, 'page_size': 25, 'page_total': 1, 'studies': {'OSD-137': {'file_count': 412, 'study_files': [{'category': 'Study Metadata Files', 'date_created': 1690945916.755, 'date_updated': 1690945916.755, 'file_name': 'OSD-137_metadata_OSD-137-ISA.zip', 'file_size': 128315, 'organization': 'OSD', 'remote_url': '/geode-py/ws/studies/OSD-137/download?source=datamanager&file=OSD-137_metadata_OSD-137-ISA.zip', 'restricted': False, 'subcategory': '', 'subdirectory': '', 'visible': True}, {'category': 'Histology', 'date_created': 1686100768.452, 'date_updated': 1686100768.452, 'file_name': 'LSDS-28_Histology_OSD_137_Histology_Submitted_Results.xlsx', 'file_size': 11793, 'organization': 'alsda', 'remote_url': '/geode-py/ws/studies/OSD-137/download?source=datamanager&file=LSDS-28_Histology_OSD_137_Histology_Submitted_Results.xlsx', 'restricted': False, 'subcategory': 'Tabular Result Files', 'subdirectory': 'Original Submitted', 'visible': True}, {'cat
# ...

# %%
from requests.api import head

# %%
remote_url ='/geode-py/ws/studies/OSD-137/download?source=datamanager&file=GLDS-137_rna_seq_bulkRNASeq_v1_runsheet.csv'

base_url = 'https://genelab-data.ndc.nasa.gov'


download_url = base_url + remote_url


local_filename = 'GLDS-137_rna_seq_bulkRNASeq_v1_runsheet.csv'


response = requests.get(download_url)

if response.status_code == 200:
    with open(local_filename, 'wb') as file:
        file.write(response.content)
    print(f"File '{local_filename}' has been successfully downloaded.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File 'GLDS-137_rna_seq_bulkRNASeq_v1_runsheet.csv' has been successfully downloaded.

# %%
remote_url ='/geode-py/ws/studies/OSD-137/download?source=datamanager&file=GLDS-137_rna_seq_Mmus_BAL-TAL_LVR_GC_Rep3_G3_R1_trimmed_fastqc.zip'

base_url = 'https://genelab-data.ndc.nasa.gov'


download_url = base_url + remote_url


local_filename = 'GeneLab Processed RNA-Seq Files'


response = requests.get(download_url)

if response.status_code == 200:
    with open(local_filename, 'wb') as file:
        file.write(response.content)
    print(f"File '{local_filename}' has been successfully downloaded.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File 'GeneLab Processed RNA-Seq Files' has been successfully downloaded.

# %%
remote_url = 'https://genelab-data.ndc.nasa.gov/geode-py/ws/studies/GLDS-137/download?source=datamanager&file=GLDS-137_rna_seq_Mmus_BAL-TAL_LVR_BSL_Rep1_B1_R1_raw.fastq.gz'


base_url = 'https://genelab-data.ndc.nasa.gov'


download_url = base_url + remote_url


local_filename = ''


response = requests.get(download_url)

if response.status_code == 200:
    with open(local_filename, 'wb') as file:
        file.write(response.content)
    print(f"File '{local_filename}' has been successfully downloaded.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
# Out:
# File 'OSD-137_metadata_OSD-137-ISA.zip' has been successfully downloaded.

# %%
remote_url = '/geode-py/ws/studies/OSD-137/download?source=datamanager&file=GLDS-137_rna-seq_RR3-GC-G7.tar.gz'

base_url = 'https://genelab-data.ndc.nasa.gov'


download_url = base_url + remote_url


local_filename = 'GLDS-137_rna-seq_RR3-GC-G7.tar.gz'


response = requests.get(download_url)

if response.status_code == 200:
    with open(local_filename, 'wb') as file:
        file.write(response.content)
    print(f"File '{local_filename}' has been successfully downloaded.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")

# %%
remote_url = '/geode-py/ws/studies/OSD-137/download?source=datamanager&file=GLDS-137_rna-seq_RR3-GC-G7.tar.gz'

base_url = 'https://genelab-data.ndc.nasa.gov'


download_url = base_url + remote_url


local_filename = 'GLGLDS-137_rna-seq_RR3-GC-G7.tar.gz'


response = requests.get(download_url)

if response.status_code == 200:
    with open(local_filename, 'wb') as file:
        file.write(response.content)
    print(f"File '{local_filename}' has been successfully downloaded.")
else:
    print(f"Failed to download the file. Status code: {response.status_code}")
